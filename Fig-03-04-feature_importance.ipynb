# %% [markdown]
# ## Figure 4: Feature importance
#
# This notebook reproduces Figure 4. It also includes boxplots showing the distributions of the most importance features.

# %%
use_extracted_data = False

# %%
import os
from string import ascii_uppercase

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from joblib import load

from lib.check_files import (
    check_prepared_data,
)
from lib.feature_importance import (
    calculate_importances,
    get_ranks,
    plot_correlations,
    plot_importances,
)
from lib.misc import format_feature_name
from lib.pu import (
    COLUMNS_TO_DROP,
    CORRELATED_COLUMNS,
    PRESERVATION_COLUMNS,
)

# %%
colour = True

colours = {
    "All": "green",
    "NA": "red",
    "SA": "blue",
}
boxprops = {
    "All": {"hatch": "x"},
    "NA": {"hatch": "\\"},
    "SA": {"hatch": "/"},
}
for key, value in boxprops.items():
    if colour:
        col = colours[key]
    else:
        col = "none"
    value["facecolor"] = col

# %% [markdown]
# ### Load PU classifiers and training data

# %%
if use_extracted_data:
    data_dir = "extracted_data"
else:
    data_dir = "prepared_data"
    check_prepared_data(data_dir, verbose=True)
training_filename = os.path.join(data_dir, "training_data.csv")
outputs_dir = "outputs"

figures_dir = "figures"
os.makedirs(figures_dir, exist_ok=True)
supplement_dir = "supplementary_figures"
os.makedirs(supplement_dir, exist_ok=True)

regions = ("All", "NA", "SA")
models = {}
for region in regions:
    if region == "All":
        classifier_filename = "pu_classifier.joblib"
    else:
        classifier_filename = f"pu_classifier_{region}.joblib"
    classifier_filename = os.path.join(
        outputs_dir,
        classifier_filename,
    )
    models[region] = load(classifier_filename)

df_training = pd.read_csv(training_filename)
importances_basename = os.path.join(figures_dir, "Fig-03-feature_importances")
boxplots_filename = os.path.join(figures_dir, "Fig-04-feature_boxplots")
correlation_filename = os.path.join(supplement_dir, "feature_importance_correlation")

to_drop = COLUMNS_TO_DROP | CORRELATED_COLUMNS | PRESERVATION_COLUMNS
to_drop.add("label")
feature_names = sorted(set(df_training.columns).difference(to_drop))
feature_names = np.array(feature_names, dtype="object")

# %% [markdown]
# ### Calculate feature importances

# %%
importances = {
    region: calculate_importances(model, feature_names)
    for region, model in models.items()
}

pd.concat(
    [
        pd.DataFrame(
            {
                f"{region}: importance (relative)": values / values.max(),
                f"{region}: importance (absolute)": values,
            }
        )
        for region, values in importances.items()
    ],
    axis="columns",
).sort_values(by="All: importance (relative)", ascending=False)
# Out:
#                                                     All: importance (relative)  \
# crustal_thickness_mean (m)                                            1.000000
# distance_to_trench (km)                                               0.371436
# convergence_rate_orthogonal (cm/yr)                                   0.361992
# trench_velocity_orthogonal (cm/yr)                                    0.316525
# seafloor_spreading_rate (km/Myr)                                      0.292764
# subducted_carbonates_volume (m)                                       0.230295
# seafloor_age (Ma)                                                     0.191958
# subducting_plate_absolute_velocity_orthogonal (...                    0.181960
# trench_velocity_obliquity (degrees)                                   0.176113
# subducted_sediment_volume (m)                                         0.169058
# carbonate_thickness (m)                                               0.167057
# convergence_obliquity (degrees)                                       0.166891
# trench_velocity_parallel (cm/yr)                                      0.165897
# magnetic_anomaly_std (nT)                                             0.163835
# slab_flux (m^2/yr)                                                    0.162527
# co2_volume (m^3/m^2)                                                  0.157336
# crustal_thickness_std (m)                                             0.150506
# subducting_plate_absolute_obliquity (degrees)                         0.146143
# sediment_thickness (m)                                                0.142076
# distance_to_trench_edge (degrees)                                     0.140653
# subducted_plate_volume (m)                                            0.139855
# subducting_plate_absolute_velocity_parallel (cm...                    0.128568
# convergence_rate_parallel (cm/yr)                                     0.121162
# magnetic_anomaly_min (nT)                                             0.089639
# magnetic_anomaly_mean (nT)                                            0.081363
#
#                                                     All: importance (absolute)  \
# crustal_thickness_mean (m)                                            0.184651
# distance_to_trench (km)                                               0.068586
# convergence_rate_orthogonal (cm/yr)                                   0.066842
# trench_velocity_orthogonal (cm/yr)                                    0.058447
# seafloor_spreading_rate (km/Myr)                                      0.054059
# subducted_carbonates_volume (m)                                       0.042524
# seafloor_age (Ma)                                                     0.035445
# subducting_plate_absolute_velocity_orthogonal (...                    0.033599
# trench_velocity_obliquity (degrees)                                   0.032520
# subducted_sediment_volume (m)                                         0.031217
# carbonate_thickness (m)                                               0.030847
# convergence_obliquity (degrees)                                       0.030817
# trench_velocity_parallel (cm/yr)                                      0.030633
# magnetic_anomaly_std (nT)                                             0.030252
# slab_flux (m^2/yr)                                                    0.030011
# co2_volume (m^3/m^2)                                                  0.029052
# crustal_thickness_std (m)                                             0.027791
# subducting_plate_absolute_obliquity (degrees)                         0.026986
# sediment_thickness (m)                                                0.026235
# distance_to_trench_edge (degrees)                                     0.025972
# subducted_plate_volume (m)                                            0.025824
# subducting_plate_absolute_velocity_parallel (cm...                    0.023740
# convergence_rate_parallel (cm/yr)                                     0.022373
# magnetic_anomaly_min (nT)                                             0.016552
# magnetic_anomaly_mean (nT)                                            0.015024
#
#                                                     NA: importance (relative)  \
# crustal_thickness_mean (m)                                           1.000000
# distance_to_trench (km)                                              0.300265
# convergence_rate_orthogonal (cm/yr)                                  0.272213
# trench_velocity_orthogonal (cm/yr)                                   0.494790
# seafloor_spreading_rate (km/Myr)                                     0.276646
# subducted_carbonates_volume (m)                                      0.124070
# seafloor_age (Ma)                                                    0.294131
# subducting_plate_absolute_velocity_orthogonal (...                   0.180782
# trench_velocity_obliquity (degrees)                                  0.161538
# subducted_sediment_volume (m)                                        0.148279
# carbonate_thickness (m)                                              0.138272
# convergence_obliquity (degrees)                                      0.177560
# trench_velocity_parallel (cm/yr)                                     0.140432
# magnetic_anomaly_std (nT)                                            0.209470
# slab_flux (m^2/yr)                                                   0.124123
# co2_volume (m^3/m^2)                                                 0.173979
# crustal_thickness_std (m)                                            0.100359
# subducting_plate_absolute_obliquity (degrees)                        0.134695
# sediment_thickness (m)                                               0.138255
# distance_to_trench_edge (degrees)                                    0.135303
# subducted_plate_volume (m)                                           0.148445
# subducting_plate_absolute_velocity_parallel (cm...                   0.107587
# convergence_rate_parallel (cm/yr)                                    0.140328
# magnetic_anomaly_min (nT)                                            0.070451
# magnetic_anomaly_mean (nT)                                           0.084783
#
#                                                     NA: importance (absolute)  \
# crustal_thickness_mean (m)                                           0.189510
# distance_to_trench (km)                                              0.056903
# convergence_rate_orthogonal (cm/yr)                                  0.051587
# trench_velocity_orthogonal (cm/yr)                                   0.093768
# seafloor_spreading_rate (km/Myr)                                     0.052427
# subducted_carbonates_volume (m)                                      0.023512
# seafloor_age (Ma)                                                    0.055741
# subducting_plate_absolute_velocity_orthogonal (...                   0.034260
# trench_velocity_obliquity (degrees)                                  0.030613
# subducted_sediment_volume (m)                                        0.028100
# carbonate_thickness (m)                                              0.026204
# convergence_obliquity (degrees)                                      0.033650
# trench_velocity_parallel (cm/yr)                                     0.026613
# magnetic_anomaly_std (nT)                                            0.039697
# slab_flux (m^2/yr)                                                   0.023523
# co2_volume (m^3/m^2)                                                 0.032971
# crustal_thickness_std (m)                                            0.019019
# subducting_plate_absolute_obliquity (degrees)                        0.025526
# sediment_thickness (m)                                               0.026201
# distance_to_trench_edge (degrees)                                    0.025641
# subducted_plate_volume (m)                                           0.028132
# subducting_plate_absolute_velocity_parallel (cm...                   0.020389
# convergence_rate_parallel (cm/yr)                                    0.026594
# magnetic_anomaly_min (nT)                                            0.013351
# magnetic_anomaly_mean (nT)                                           0.016067
#
#                                                     SA: importance (relative)  \
# crustal_thickness_mean (m)                                           1.000000
# distance_to_trench (km)                                              0.696984
# convergence_rate_orthogonal (cm/yr)                                  0.276615
# trench_velocity_orthogonal (cm/yr)                                   0.164515
# seafloor_spreading_rate (km/Myr)                                     0.216975
# subducted_carbonates_volume (m)                                      0.406013
# seafloor_age (Ma)                                                    0.171145
# subducting_plate_absolute_velocity_orthogonal (...                   0.204368
# trench_velocity_obliquity (degrees)                                  0.360551
# subducted_sediment_volume (m)                                        0.109019
# carbonate_thickness (m)                                              0.298382
# convergence_obliquity (degrees)                                      0.224814
# trench_velocity_parallel (cm/yr)                                     0.339050
# magnetic_anomaly_std (nT)                                            0.114477
# slab_flux (m^2/yr)                                                   0.440140
# co2_volume (m^3/m^2)                                                 0.200751
# crustal_thickness_std (m)                                            0.256954
# subducting_plate_absolute_obliquity (degrees)                        0.169767
# sediment_thickness (m)                                               0.119304
# distance_to_trench_edge (degrees)                                    0.148092
# subducted_plate_volume (m)                                           0.109073
# subducting_plate_absolute_velocity_parallel (cm...                   0.156600
# convergence_rate_parallel (cm/yr)                                    0.157835
# magnetic_anomaly_min (nT)                                            0.092764
# magnetic_anomaly_mean (nT)                                           0.099076
#
#                                                     SA: importance (absolute)
# crustal_thickness_mean (m)                                           0.153063
# distance_to_trench (km)                                              0.106682
# convergence_rate_orthogonal (cm/yr)                                  0.042340
# trench_velocity_orthogonal (cm/yr)                                   0.025181
# seafloor_spreading_rate (km/Myr)                                     0.033211
# subducted_carbonates_volume (m)                                      0.062146
# seafloor_age (Ma)                                                    0.026196
# subducting_plate_absolute_velocity_orthogonal (...                   0.031281
# trench_velocity_obliquity (degrees)                                  0.055187
# subducted_sediment_volume (m)                                        0.016687
# carbonate_thickness (m)                                              0.045671
# convergence_obliquity (degrees)                                      0.034411
# trench_velocity_parallel (cm/yr)                                     0.051896
# magnetic_anomaly_std (nT)                                            0.017522
# slab_flux (m^2/yr)                                                   0.067369
# co2_volume (m^3/m^2)                                                 0.030727
# crustal_thickness_std (m)                                            0.039330
# subducting_plate_absolute_obliquity (degrees)                        0.025985
# sediment_thickness (m)                                               0.018261
# distance_to_trench_edge (degrees)                                    0.022667
# subducted_plate_volume (m)                                           0.016695
# subducting_plate_absolute_velocity_parallel (cm...                   0.023970
# convergence_rate_parallel (cm/yr)                                    0.024159
# magnetic_anomaly_min (nT)                                            0.014199
# magnetic_anomaly_mean (nT)                                           0.015165

# %% [markdown]
# ### Plot feature importances (bar chart)

# %%
normalise = True  # show relative importance values
num_to_keep = 6  # show 6 most important features

# %%
fig, axs = plt.subplots(
    3, 1,
    figsize=(num_to_keep * 1.33, num_to_keep * 1.87),
    gridspec_kw={"hspace": 0.17},
)
for ax, region in zip(axs, regions):
    title = f"Top {num_to_keep} features ({region})"
    plot_importances(
        models[region],
        names=feature_names,
        normalise=normalise,
        num_to_keep=num_to_keep,
        ax=ax,
        title=title,
        fontsize=12,
        titlesize=19.2,
    )
    if ax is not axs[-1]:
        ax.set_xlabel(None)
        ax.tick_params(labelbottom=False)

for extension in (".png", ".pdf"):
    output_filename = importances_basename + extension
    fig.savefig(
        output_filename,
        dpi=350,
        bbox_inches="tight",
    )

# %% [markdown]
# ### Compare feature importance rankings

# %%
importances = {
    region: calculate_importances(model, feature_names)
    for region, model in models.items()
}
ranks = {
    region: get_ranks(values) for region, values in importances.items()
}
ranks = pd.concat(
    [
        pd.DataFrame(rank_values, columns=[f"Rank ({region})"])
        for region, rank_values in ranks.items()
    ],
    axis="columns",
)

# %%
sort_by = "All"

ranks.sort_values(f"Rank ({sort_by})")
# Out:
#                                                     Rank (All)  Rank (NA)  \
# crustal_thickness_mean (m)                                   1          1
# distance_to_trench (km)                                      2          3
# convergence_rate_orthogonal (cm/yr)                          3          6
# trench_velocity_orthogonal (cm/yr)                           4          2
# seafloor_spreading_rate (km/Myr)                             5          5
# subducted_carbonates_volume (m)                              6         21
# seafloor_age (Ma)                                            7          4
# subducting_plate_absolute_velocity_orthogonal (...           8          8
# trench_velocity_obliquity (degrees)                          9         11
# subducted_sediment_volume (m)                               10         13
# carbonate_thickness (m)                                     11         16
# convergence_obliquity (degrees)                             12          9
# trench_velocity_parallel (cm/yr)                            13         14
# magnetic_anomaly_std (nT)                                   14          7
# slab_flux (m^2/yr)                                          15         20
# co2_volume (m^3/m^2)                                        16         10
# crustal_thickness_std (m)                                   17         23
# subducting_plate_absolute_obliquity (degrees)               18         19
# sediment_thickness (m)                                      19         17
# distance_to_trench_edge (degrees)                           20         18
# subducted_plate_volume (m)                                  21         12
# subducting_plate_absolute_velocity_parallel (cm...          22         22
# convergence_rate_parallel (cm/yr)                           23         15
# magnetic_anomaly_min (nT)                                   24         25
# magnetic_anomaly_mean (nT)                                  25         24
#
#                                                     Rank (SA)
# crustal_thickness_mean (m)                                  1
# distance_to_trench (km)                                     2
# convergence_rate_orthogonal (cm/yr)                         8
# trench_velocity_orthogonal (cm/yr)                         16
# seafloor_spreading_rate (km/Myr)                           11
# subducted_carbonates_volume (m)                             4
# seafloor_age (Ma)                                          14
# subducting_plate_absolute_velocity_orthogonal (...         12
# trench_velocity_obliquity (degrees)                         5
# subducted_sediment_volume (m)                              23
# carbonate_thickness (m)                                     7
# convergence_obliquity (degrees)                            10
# trench_velocity_parallel (cm/yr)                            6
# magnetic_anomaly_std (nT)                                  21
# slab_flux (m^2/yr)                                          3
# co2_volume (m^3/m^2)                                       13
# crustal_thickness_std (m)                                   9
# subducting_plate_absolute_obliquity (degrees)              15
# sediment_thickness (m)                                     20
# distance_to_trench_edge (degrees)                          19
# subducted_plate_volume (m)                                 22
# subducting_plate_absolute_velocity_parallel (cm...         18
# convergence_rate_parallel (cm/yr)                          17
# magnetic_anomaly_min (nT)                                  25
# magnetic_anomaly_mean (nT)                                 24

# %%
fig = plot_correlations(
    models,
    names=feature_names,
    verbose=True,
    cmap="plasma" if colour else "Greys",
    text_kw={"color": "black" if colour else "white"}
)
for ext in (".pdf", ".png"):
    output_filename = correlation_filename + ext
    fig.savefig(output_filename, dpi=350, bbox_inches="tight")
# Out:
# All/NA: tau = 0.60, p = 0.00
# All/SA: tau = 0.49, p = 0.00
# NA/SA: tau = 0.22, p = 0.06

# %% [markdown]
# ### Plot important feature distributions (box plots)

# %%
importances_sorted = importances["All"].sort_values(ascending=False)
columns = importances_sorted.iloc[:num_to_keep].index

df_boxplots = df_training.copy()
df_boxplots = df_boxplots[df_boxplots["region"].isin({"NAm", "SAm"})]

mean_values = pd.concat(
    [
        df_boxplots,
        df_boxplots.assign(region="All"),
    ]
).groupby(["region", "label"])[columns].mean()
print("Mean values:")
mean_values.T
# Out:
# Mean values:
# region                                        All                              \
# label                                    negative      positive    unlabelled
# crustal_thickness_mean (m)           45036.618112  46594.015383  38570.683283
# distance_to_trench (km)                370.332834    415.948199    277.418006
# convergence_rate_orthogonal (cm/yr)      7.978948      9.017506      5.623068
# trench_velocity_orthogonal (cm/yr)      -0.568777     -2.203915     -0.914783
# seafloor_spreading_rate (km/Myr)       100.533424    118.214227     87.182149
# subducted_carbonates_volume (m)       1603.454966    339.846246    207.082500
#
# region                                        NAm                              \
# label                                    negative      positive    unlabelled
# crustal_thickness_mean (m)           35824.774054  47539.517326  39151.725505
# distance_to_trench (km)                219.424041    406.638555    274.153981
# convergence_rate_orthogonal (cm/yr)      5.040007      9.027425      5.034337
# trench_velocity_orthogonal (cm/yr)      -1.108740     -2.766340     -1.103310
# seafloor_spreading_rate (km/Myr)       116.739547    109.388207     80.647479
# subducted_carbonates_volume (m)        247.304046    299.675457    200.441820
#
# region                                        SAm
# label                                    negative      positive    unlabelled
# crustal_thickness_mean (m)           45867.433161  45015.754447  37976.185745
# distance_to_trench (km)                383.943279    431.488145    281.240567
# convergence_rate_orthogonal (cm/yr)      8.244011      9.000948      6.312542
# trench_velocity_orthogonal (cm/yr)      -0.520078     -1.265097     -0.693997
# seafloor_spreading_rate (km/Myr)        99.071796    132.946891     94.835023
# subducted_carbonates_volume (m)       1725.766045    406.900564    214.859525

# %%
label_filters = {
    i: df_boxplots["label"] == i
    for i in ("positive", "unlabelled")
}
region_filters = {
    "All": np.full(df_boxplots.shape[0], True),
    **{i: df_boxplots["region"] == i + "m" for i in ("NA", "SA")}
}

disp = 0.25
fontsize = 13
titlesize = fontsize * 1.15

data = []
keys = []
positions = []
for i, label in enumerate(label_filters.keys()):
    for j, region in enumerate(("NA", "All", "SA")):
        filt = (label_filters[label]) & (region_filters[region])
        keys.append((label, region))
        data.append(df_boxplots[filt])
        positions.append(i + (j - 1) * disp)
positions = np.array(positions)
xlims = (positions.min() - disp, positions.max() + disp)

fig, axs = plt.subplots(
    3, 2,
    figsize=(12, 12),
    gridspec_kw={"hspace": 0.18},
)

for i, (column, ax) in enumerate(
    zip(
        columns,
        np.ravel(axs),
    )
):
    panel_label = ascii_uppercase[i]
    for d, key, position in zip(data, keys, positions):
        label, region = key
        ticklabel = region
        if i >= num_to_keep - 2:
            if region == "All":
                if label == "positive":
                    ticklabel += "\n(positive)"
                else:
                    ticklabel += "\n(random)"
        else:
            ticklabel = ""

        ax.boxplot(
            d[column].dropna(),
            positions=[position],
            patch_artist=True,
            boxprops={**(boxprops[region]), "alpha": 0.25},
            showfliers=False,
            showmeans=True,
            meanprops=dict(
                marker="^",
                markerfacecolor="black",
                markeredgecolor="black",
                markersize=8,
            ),
            medianprops=dict(
                color="red",
                linewidth=1.5,
            ),
            labels=[ticklabel],
            widths=[disp * 0.8],
        )

    ax.text(
        0.025, 0.95,
        panel_label,
        ha="left",
        va="top",
        fontsize=titlesize,
        transform=ax.transAxes,
        bbox=dict(
            facecolor="white",
            edgecolor="lightgrey",
            linewidth=0.5,
            boxstyle="Round, pad=0.15, rounding_size=0.15",
        )
    )
    ax.set_title(format_feature_name(column), fontsize=titlesize)
    ax.set_xlim(*xlims)
    ax.grid(linestyle="dashed", color="grey", alpha=0.5, axis="y")
    ax.tick_params(labelsize=fontsize)

for ext in (".png", ".pdf"):
    output_filename = boxplots_filename + ext
    fig.savefig(
        output_filename,
        dpi=350,
        bbox_inches="tight",
    )
